# %%
import nltk #natural language tootl kit
import pandas as pd

# %%
nltk.download_shell()#the NLTK corpus and module downloader
#this module defines several interface which can be used to download
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopwords
# ...
#       Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q

# %%
messages=[line.rstrip() for line in open("/content/sample_data/SMSSpamCollection")]
#The rstrip() method removes any trailing characters

# %%
print(len(messages))
# Out:
# 5574

# %%
messages[0]
# Out:
# 'ham\tGo until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %%
for mess_no,message in enumerate(messages[:10]): #enumerate-count
  print(mess_no,message)
print("\n")
# Out:
# 0 ham	Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 1 ham	Ok lar... Joking wif u oni...
# 2 spam	Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's
# 3 ham	U dun say so early hor... U c already then say...
# 4 ham	Nah I don't think he goes to usf, he lives around here though
# 5 spam	FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv
# 6 ham	Even my brother is not like to speak with me. They treat me like aids patent.
# 7 ham	As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune
# ...

# %%
messages=pd.read_csv('/content/sample_data/SMSSpamCollection',sep='\t',names=['label','message'])
#read using csv, sep-seperate with /t , names=names the label

# %%
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#classification needs numerical feature,convert string into,vector format-use bag of words
#1)function to split words from sentence into list
#2)Remocve stopwords(a,an,the etc)
#bag of words reference- https://machinelearningmastery.com/gentle-introduction-bag-words-model/

import string

# %% [markdown]
# sample code for removing punctuations and stop words

# %%
mess="sample message! notice: its has punctuation"
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
nopunc=[i for i in mess if i not in string.punctuation]
nopunc
# Out:
# ['s',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  ' ',
#  'm',
#  'e',
#  's',
#  's',
#  'a',
#  'g',
#  'e',
#  ' ',
#  'n',
#  'o',
#  't',
#  'i',
#  'c',
#  'e',
#  ' ',
#  'i',
#  't',
#  's',
#  ' ',
#  'h',
#  'a',
#  's',
#  ' ',
#  'p',
#  'u',
#  'n',
#  'c',
#  't',
#  'u',
#  'a',
#  't',
#  'i',
#  'o',
#  'n']

# %%
nopunc=''.join(nopunc)
nopunc
# Out:
# 'sample message notice its has punctuation'

# %%
#removing stopword
nopunc.split()
# Out:
# ['sample', 'message', 'notice', 'its', 'has', 'punctuation']

# %%
#import stopwords using following methods if not found stopwords
#(1)from nltk.corpus import stopwords
#(2)(2.1)import nltk
#(2.2)nltk.download('stopwords')

# %%
#check if the splited words have stopwords or not
#and if it is in upperconvet tolowercase
clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words("english")]

# %%
clean_mess
# Out:
# ['sample', 'message', 'notice', 'punctuation']

# %%
def text_process(mess):
  """
  1.Remove punc
  2.Remove stopwords
  3.return list of cleantextwords
  """

  nopunc=[i for i in mess if i not in string.punctuation]
  nopunc=''.join(nopunc)
  return[word for word in nopunc.split() if word.lower() not in stopwords.words("english")]

# %%
messages['message'].head(5).apply(text_process)
# Out:
# 0    [Go, jurong, point, crazy, Available, bugis, n...
# 1                       [Ok, lar, Joking, wif, u, oni]
# 2    [Free, entry, 2, wkly, comp, win, FA, Cup, fin...
# 3        [U, dun, say, early, hor, U, c, already, say]
# 4    [Nah, dont, think, goes, usf, lives, around, t...
# Name: message, dtype: object
